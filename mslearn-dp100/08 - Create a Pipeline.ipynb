# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets; either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.45.0 to work with Preparation-AI102-Florian

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it previously, the code will find the existing version)

# %%
from azureml.core import Dataset
from azureml.data.datapath import DataPath

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    Dataset.File.upload_directory(src_dir='data',
                              target=DataPath(default_ds, 'diabetes-data/')
                              )

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Overwriting diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-data**, which references the location where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-data", type=str, dest='training_data', help='training data')
args = parser.parse_args()
training_data = args.training_data

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_data,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "your-compute-cluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
    
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# InProgress..
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# The compute will require a Python environment with the necessary package dependencies installed.

# %%
# %%writefile $experiment_folder/experiment_env.yml
# name: experiment_env
# dependencies:
# - python=3.6.2
# - scikit-learn
# - ipykernel
# - matplotlib
# - pandas
# - pip
# - pip:
#   - azureml-defaults
#   - pyarrow
# Out:
# Overwriting diabetes_pipeline/experiment_env.yml

# %% [markdown]
# Now that you have a Conda configuration file, you can create an environment and use it in the run configuration for the pipeline.

# %%
from azureml.core import Environment
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment (from a .yml file)
experiment_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/experiment_env.yml")

# Register the environment 
experiment_env.register(workspace=ws)
registered_env = Environment.get(ws, 'experiment_env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to be passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **OutputFileDatasetConfig** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you need to pass it as a script argument so your code can access the datastore location referenced by the data reference.

# %%
from azureml.data import OutputFileDatasetConfig
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create an OutputFileDatasetConfig (temporary Data Reference) for data passed from step 1 to step 2
prepped_data = OutputFileDatasetConfig("prepped_data")

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-data', prepped_data.as_input()],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps,)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [cc5d8339][c13641d0-24b7-4857-b6d7-74a8ed4d3ba9], (This step will run and generate new outputs)
# Created step Train and Register Model [fcbbaee6][71568067-5b7f-468e-8d76-1c2b1d9cdbde], (This step will run and generate new outputs)
# Submitted PipelineRun 4b165e02-edf3-458d-94a6-7d6a5f2b76e5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4b165e02-edf3-458d-94a6-7d6a5f2b76e5?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 4b165e02-edf3-458d-94a6-7d6a5f2b76e5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4b165e02-edf3-458d-94a6-7d6a5f2b76e5?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# PipelineRun Status: Running
#
#
# StepRunId: d9fc46be-bdf1-4c83-a1d2-7043ce751ea8
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/d9fc46be-bdf1-4c83-a1d2-7043ce751ea8?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/09/26 19:03:09 Downloading source code...
# 2022/09/26 19:03:10 Finished downloading source code
# 2022/09/26 19:03:10 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/09/26 19:03:10 Successfully set up Docker network: acb_default_network
# 2022/09/26 19:03:10 Setting up Docker configuration...
# 2022/09/26 19:03:11 Successfully set up Docker configuration
# 2022/09/26 19:03:11 Logging in to registry: 1e8b8819e21c490c89804742dee21367.azurecr.io
# 2022/09/26 19:03:11 Successfully logged into 1e8b8819e21c490c89804742dee21367.azurecr.io
# 2022/09/26 19:03:11 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/26 19:03:11 Scanning for dependencies...
# 2022/09/26 19:03:12 Successfully scanned dependencies
# 2022/09/26 19:03:12 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1@sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1@sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d7bfe07ed847: Pulling fs layer
# 1e1c6f32e53a: Pulling fs layer
# 5bd7167b78fb: Pulling fs layer
# 7692bb371255: Pulling fs layer
# 4ab61f330ff9: Pulling fs layer
# 4f52b9f71c0c: Pulling fs layer
# 4a25856e15bf: Pulling fs layer
# e851225f62a6: Pulling fs layer
# 2eed56b7bde9: Pulling fs layer
# 8dcad2ef365c: Pulling fs layer
# 4f52b9f71c0c: Waiting
# 4a25856e15bf: Waiting
# e851225f62a6: Waiting
# 2eed56b7bde9: Waiting
# 7692bb371255: Waiting
# 4ab61f330ff9: Waiting
# 8dcad2ef365c: Waiting
# d7bfe07ed847: Verifying Checksum
# d7bfe07ed847: Download complete
# 5bd7167b78fb: Verifying Checksum
# 5bd7167b78fb: Download complete
# 4ab61f330ff9: Verifying Checksum
# 4ab61f330ff9: Download complete
# 7692bb371255: Verifying Checksum
# 7692bb371255: Download complete
# 4a25856e15bf: Verifying Checksum
# 4a25856e15bf: Download complete
# 4f52b9f71c0c: Verifying Checksum
# 4f52b9f71c0c: Download complete
# e851225f62a6: Verifying Checksum
# e851225f62a6: Download complete
# 8dcad2ef365c: Verifying Checksum
# 8dcad2ef365c: Download complete
# 1e1c6f32e53a: Verifying Checksum
# 1e1c6f32e53a: Download complete
# 2eed56b7bde9: Verifying Checksum
# 2eed56b7bde9: Download complete
# d7bfe07ed847: Pull complete
# 1e1c6f32e53a: Pull complete
# 5bd7167b78fb: Pull complete
# 7692bb371255: Pull complete
# 4ab61f330ff9: Pull complete
# 4f52b9f71c0c: Pull complete
# 4a25856e15bf: Pull complete
# e851225f62a6: Pull complete
# 2eed56b7bde9: Pull complete
# 8dcad2ef365c: Pull complete
# Digest: sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1@sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
#  ---> 66ef907b4cf1
# Step 2/21 : USER root
#  ---> Running in 63eed01fd8b2
# Removing intermediate container 63eed01fd8b2
#  ---> d579314bd0cf
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in ef792babe816
# Removing intermediate container ef792babe816
#  ---> 3eeafa433853
# Step 4/21 : WORKDIR /
#  ---> Running in ab5f2a3b5416
# Removing intermediate container ab5f2a3b5416
#  ---> 8cdaa6dab948
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 7f2952cb6f0d
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in eccc0c6c9455
# Removing intermediate container eccc0c6c9455
#  ---> 96b97d6f3e9a
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 4cc855df9cba
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in b013aa96f52a
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# decorator-5.1.1      | 12 KB     |            |   0%
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# expat-2.4.4          | 169 KB    |            |   0%
# expat-2.4.4          | 169 KB    | ########## | 100%
#
# pcre-8.45            | 207 KB    |            |   0%
# pcre-8.45            | 207 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# openjpeg-2.4.0       | 331 KB    |            |   0%
# openjpeg-2.4.0       | 331 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# tk-8.6.12            | 3.0 MB    |            |   0%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
#
# lerc-3.0             | 196 KB    |            |   0%
# lerc-3.0             | 196 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# jupyter_client-7.1.2 | 93 KB     |            |   0%
# jupyter_client-7.1.2 | 93 KB     | ########## | 100%
#
# ca-certificates-2022 | 124 KB    |            |   0%
# ca-certificates-2022 | 124 KB    | ########## | 100%
#
# pexpect-4.8.0        | 53 KB     |            |   0%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
# pillow-8.3.1         | 637 KB    |            |   0%
# pillow-8.3.1         | 637 KB    | ########## | 100%
#
# zstd-1.5.2           | 488 KB    |            |   0%
# zstd-1.5.2           | 488 KB    | ########## | 100%
#
# libuuid-1.0.3        | 17 KB     |            |   0%
# libuuid-1.0.3        | 17 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 4.8 MB    |            |   0%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
#
# libxml2-2.9.14       | 718 KB    |            |   0%
# libxml2-2.9.14       | 718 KB    | ########## | 100%
#
# lz4-c-1.9.3          | 185 KB    |            |   0%
# lz4-c-1.9.3          | 185 KB    | ########## | 100%
#
# dbus-1.13.18         | 504 KB    |            |   0%
# dbus-1.13.18         | 504 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.1 MB    |            |   0%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# parso-0.8.3          | 70 KB     |            |   0%
# parso-0.8.3          | 70 KB     | ########## | 100%
#
# ipykernel-5.3.4      | 181 KB    |            |   0%
# ipykernel-5.3.4      | 181 KB    | 8          |   9%
# ipykernel-5.3.4      | 181 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | #####3     |  54%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | #7         |  17%
# python-3.6.2         | 23.6 MB   | ####9      |  50%
# python-3.6.2         | 23.6 MB   | #########1 |  91%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# pytz-2021.3          | 171 KB    |            |   0%
# pytz-2021.3          | 171 KB    | ########## | 100%
#
# kiwisolver-1.3.1     | 86 KB     |            |   0%
# kiwisolver-1.3.1     | 86 KB     | ########## | 100%
#
# traitlets-4.3.3      | 138 KB    |            |   0%
# traitlets-4.3.3      | 138 KB    | #1         |  12%
# traitlets-4.3.3      | 138 KB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# libxcb-1.15          | 505 KB    |            |   0%
# libxcb-1.15          | 505 KB    | ########## | 100%
#
# pyzmq-22.2.1         | 454 KB    |            |   0%
# pyzmq-22.2.1         | 454 KB    | 3          |   4%
# pyzmq-22.2.1         | 454 KB    | ########## | 100%
# pyzmq-22.2.1         | 454 KB    | ########## | 100%
#
# libtiff-4.4.0        | 471 KB    |            |   0%
# libtiff-4.4.0        | 471 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# sip-4.19.8           | 274 KB    |            |   0%
# sip-4.19.8           | 274 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# intel-openmp-2022.1. | 4.5 MB    |            |   0%
# intel-openmp-2022.1. | 4.5 MB    | ########## | 100%
# intel-openmp-2022.1. | 4.5 MB    | ########## | 100%
#
# jpeg-9e              | 240 KB    |            |   0%
# jpeg-9e              | 240 KB    | ########## | 100%
#
# cycler-0.11.0        | 12 KB     |            |   0%
# cycler-0.11.0        | 12 KB     | ########## | 100%
#
# zeromq-4.3.4         | 331 KB    |            |   0%
# zeromq-4.3.4         | 331 KB    | ########## | 100%
#
# libgcc-ng-11.2.0     | 5.3 MB    |            |   0%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 8          |   8%
# mkl-2020.2           | 138.3 MB  | #6         |  16%
# mkl-2020.2           | 138.3 MB  | ##3        |  23%
# mkl-2020.2           | 138.3 MB  | ##9        |  29%
# mkl-2020.2           | 138.3 MB  | ###5       |  36%
# mkl-2020.2           | 138.3 MB  | ####2      |  43%
# mkl-2020.2           | 138.3 MB  | #####2     |  52%
# mkl-2020.2           | 138.3 MB  | #####9     |  59%
# mkl-2020.2           | 138.3 MB  | ######6    |  66%
# mkl-2020.2           | 138.3 MB  | #######5   |  75%
# mkl-2020.2           | 138.3 MB  | ########2  |  83%
# mkl-2020.2           | 138.3 MB  | ########9  |  90%
# mkl-2020.2           | 138.3 MB  | #########6 |  97%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# entrypoints-0.3      | 12 KB     |            |   0%
# entrypoints-0.3      | 12 KB     | ########## | 100%
# entrypoints-0.3      | 12 KB     | ########## | 100%
#
# ipython-7.16.1       | 999 KB    |            |   0%
# ipython-7.16.1       | 999 KB    | 1          |   2%
# ipython-7.16.1       | 999 KB    | #6         |  16%
# ipython-7.16.1       | 999 KB    | ####       |  40%
# ipython-7.16.1       | 999 KB    | #####9     |  59%
# ipython-7.16.1       | 999 KB    | ########4  |  85%
# ipython-7.16.1       | 999 KB    | ########## | 100%
#
# libgomp-11.2.0       | 474 KB    |            |   0%
# libgomp-11.2.0       | 474 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# ptyprocess-0.7.0     | 17 KB     |            |   0%
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
# freetype-2.11.0      | 618 KB    |            |   0%
# freetype-2.11.0      | 618 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# icu-58.2             | 10.5 MB   |            |   0%
# icu-58.2             | 10.5 MB   | ########3  |  84%
# icu-58.2             | 10.5 MB   | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# jedi-0.17.0          | 780 KB    |            |   0%
# jedi-0.17.0          | 780 KB    | 2          |   2%
# jedi-0.17.0          | 780 KB    | ######7    |  68%
# jedi-0.17.0          | 780 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# nest-asyncio-1.5.1   | 10 KB     |            |   0%
# nest-asyncio-1.5.1   | 10 KB     | ########## | 100%
#
# pyqt-5.9.2           | 4.5 MB    |            |   0%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
#
# wcwidth-0.2.5        | 26 KB     |            |   0%
# wcwidth-0.2.5        | 26 KB     | ########## | 100%
#
# ipython_genutils-0.2 | 27 KB     |            |   0%
# ipython_genutils-0.2 | 27 KB     | ########## | 100%
#
# qt-5.9.6             | 67.3 MB   |            |   0%
# qt-5.9.6             | 67.3 MB   |            |   0%
# qt-5.9.6             | 67.3 MB   |            |   1%
# qt-5.9.6             | 67.3 MB   | 1          |   2%
# qt-5.9.6             | 67.3 MB   | 4          |   5%
# qt-5.9.6             | 67.3 MB   | #1         |  12%
# qt-5.9.6             | 67.3 MB   | ##         |  21%
# qt-5.9.6             | 67.3 MB   | ##6        |  26%
# qt-5.9.6             | 67.3 MB   | ###2       |  33%
# qt-5.9.6             | 67.3 MB   | ###8       |  38%
# qt-5.9.6             | 67.3 MB   | ####5      |  45%
# qt-5.9.6             | 67.3 MB   | #####1     |  52%
# qt-5.9.6             | 67.3 MB   | #####8     |  58%
# qt-5.9.6             | 67.3 MB   | #######5   |  75%
# qt-5.9.6             | 67.3 MB   | #########2 |  93%
# qt-5.9.6             | 67.3 MB   | ########## | 100%
#
# fontconfig-2.13.1    | 250 KB    |            |   0%
# fontconfig-2.13.1    | 250 KB    | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# glib-2.63.1          | 2.9 MB    |            |   0%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# pygments-2.11.2      | 759 KB    |            |   0%
# pygments-2.11.2      | 759 KB    | ########## | 100%
#
# zlib-1.2.12          | 103 KB    |            |   0%
# zlib-1.2.12          | 103 KB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# lcms2-2.12           | 312 KB    |            |   0%
# lcms2-2.12           | 312 KB    | ########## | 100%
#
# matplotlib-3.3.4     | 26 KB     |            |   0%
# matplotlib-3.3.4     | 26 KB     | ######     |  61%
# matplotlib-3.3.4     | 26 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# libsodium-1.0.18     | 244 KB    |            |   0%
# libsodium-1.0.18     | 244 KB    | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
#
# xz-5.2.5             | 339 KB    |            |   0%
# xz-5.2.5             | 339 KB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# pyparsing-3.0.4      | 81 KB     |            |   0%
# pyparsing-3.0.4      | 81 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# backcall-0.2.0       | 13 KB     |            |   0%
# backcall-0.2.0       | 13 KB     | ########## | 100%
#
# prompt-toolkit-3.0.2 | 259 KB    |            |   0%
# prompt-toolkit-3.0.2 | 259 KB    | ########## | 100%
#
# libdeflate-1.8       | 51 KB     |            |   0%
# libdeflate-1.8       | 51 KB     | ########## | 100%
#
# pandas-1.1.5         | 8.2 MB    |            |   0%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
#
# jupyter_core-4.8.1   | 74 KB     |            |   0%
# jupyter_core-4.8.1   | 74 KB     | ##1        |  22%
# jupyter_core-4.8.1   | 74 KB     | ########## | 100%
#
# libwebp-base-1.2.2   | 440 KB    |            |   0%
# libwebp-base-1.2.2   | 440 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# _openmp_mutex-5.1    | 21 KB     |            |   0%
# _openmp_mutex-5.1    | 21 KB     | ########## | 100%
#
# libpng-1.6.37        | 278 KB    |            |   0%
# libpng-1.6.37        | 278 KB    | ########## | 100%
#
# tornado-6.1          | 581 KB    |            |   0%
# tornado-6.1          | 581 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.45.0-py3-none-any.whl (2.0 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-inference-server-http~=0.7.2
#   Downloading azureml_inference_server_http-0.7.6-py3-none-any.whl (56 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.45.0
#   Downloading azureml_dataset_runtime-1.45.0-py3-none-any.whl (2.3 kB)
# Collecting azureml-core~=1.45.0
#   Downloading azureml_core-1.45.0.post2-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: numpy>=1.16.6 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 2)) (1.19.2)
# Collecting pkginfo
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.45.0->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.45.0->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (2021.3)
# Collecting jmespath<2.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.0.0-py3-none-any.whl (489 kB)
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.1.0-py3-none-any.whl (57 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.19.0-py2.py3-none-any.whl (83 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<38.0.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting azure-mgmt-storage<=20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.24.2-py3-none-any.whl (178 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azure-core<2.0.0->azureml-core~=1.45.0->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (1.16.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.2-py3-none-any.whl (26 kB)
# Collecting azureml-dataprep<4.3.0a,>=4.2.0a
#   Downloading azureml_dataprep-4.2.2-py3-none-any.whl (43.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.5 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting jsonschema
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting azureml-dataprep-rslex~=2.8.0dev0
#   Downloading azureml_dataprep_rslex-2.8.1-cp36-cp36m-manylinux2010_x86_64.whl (16.5 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.7-py2.py3-none-any.whl (42 kB)
# Collecting flask-cors~=3.0.1
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting inference-schema~=1.4.0
#   Downloading inference_schema-1.4.2.1-py3-none-any.whl (21 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting flask<2.2.0
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.7.2->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (58.0.4)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (402 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=7.1.2
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Requirement already satisfied: pygments in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.45.0->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (2.11.2)
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.45.0->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (2021.5.30)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.2-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting opencensus<1.0.0,>=0.11.0
#   Downloading opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.11.1-py2.py3-none-any.whl (167 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.3-py2.py3-none-any.whl (211 kB)
# Collecting protobuf<5.0.0dev,>=3.15.0
#   Downloading protobuf-3.19.5-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.45.0->azureml-defaults->-r /azureml-environment-setup/condaenv.a9z_vnr4.requirements.txt (line 1)) (3.0.4)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (594 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.1-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.19-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.18.0-cp36-cp36m-manylinux1_x86_64.whl (117 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=0d361435570dae62448f386b5276dbbc1aa187773d88b946d39eeb816c295fe6
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=297cde142e3ef0fd8317db940ec684cefdda3a4cb95569ce64a55c421668cee8
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=76171 sha256=8b44f2de35fdd1963c682748bf1b5036b0ccb8dff9be98917b4fbeef75906e86
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7681 sha256=6276c6bfed6f324af74d31a35d20b3b43537ed90bb7f9648983cacb03a3529dc
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, typing-extensions, requests, pyasn1, zipp, rsa, pyasn1-modules, protobuf, portalocker, oauthlib, msal, immutables, cachetools, requests-oauthlib, pyrsistent, msal-extensions, MarkupSafe, isodate, importlib-metadata, googleapis-common-protos, google-auth, distro, dataclasses, contextvars, azure-core, attrs, Werkzeug, pyyaml, opencensus-context, msrest, jsonschema, Jinja2, itsdangerous, google-api-core, dotnetcore2, cloudpickle, click, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, websocket-client, tabulate, PySocks, pyopenssl, pynacl, pyarrow, psutil, opencensus, msrestazure, jmespath, jeepney, flask, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, opencensus-ext-azure, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask-cors, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.4.0 PySocks-1.7.1 SecretStorage-3.3.3 Werkzeug-2.0.3 adal-1.2.7 argcomplete-2.0.0 attrs-22.1.0 azure-common-1.1.28 azure-core-1.24.2 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.2 azure-mgmt-keyvault-10.0.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-core-1.45.0.post2 azureml-dataprep-4.2.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.8.1 azureml-dataset-runtime-1.45.0 azureml-defaults-1.45.0 azureml-inference-server-http-0.7.6 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.0 cachetools-4.2.4 cffi-1.15.1 charset-normalizer-2.0.12 click-8.0.4 cloudpickle-2.2.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-37.0.4 dataclasses-0.8 distro-1.7.0 docker-5.0.3 dotnetcore2-3.1.23 flask-2.0.3 flask-cors-3.0.10 fusepy-3.0.1 google-api-core-2.8.2 google-auth-2.11.1 googleapis-common-protos-1.56.3 gunicorn-20.1.0 humanfriendly-10.0 idna-3.4 immutables-0.19 importlib-metadata-4.8.3 inference-schema-1.4.2.1 isodate-0.6.1 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.2.0 jsonschema-3.2.0 knack-0.9.0 msal-1.19.0 msal-extensions-0.3.1 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.1 opencensus-0.11.0 opencensus-context-0.1.3 opencensus-ext-azure-1.1.7 packaging-21.3 paramiko-2.11.0 pathspec-0.9.0 pkginfo-1.8.3 portalocker-2.5.1 protobuf-3.19.5 psutil-5.9.2 pyarrow-6.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pynacl-1.5.0 pyopenssl-22.0.0 pyrsistent-0.18.0 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.9 tabulate-0.8.10 typing-extensions-4.1.1 urllib3-1.26.12 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container b013aa96f52a
#  ---> 19cce1818b1a
# Step 9/21 : ENV PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin:$PATH
#  ---> Running in f881b4e0abb6
# Removing intermediate container f881b4e0abb6
#  ---> 2e152cefea97
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> f32dcdf8e1c0
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 573b5d3a564a
# Copying environment context
# Removing intermediate container 573b5d3a564a
#  ---> 8a8e6f2f0091
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 93a6b8f059bd
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 376bc7f08717
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 376bc7f08717
#  ---> 033c5f9c939a
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 8dd55dc37692
# Removing intermediate container 8dd55dc37692
#  ---> c2ff1715d27a
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib:$LD_LIBRARY_PATH
#  ---> Running in e155f27254b4
# Removing intermediate container e155f27254b4
#  ---> 25d50aade3e8
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_0c5a9aa2def4b3c2501c1f40287a356b CONDA_PREFIX=/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 8b87732428a8
# Removing intermediate container 8b87732428a8
#  ---> 3be53ffdff9b
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 9252aabbfe80
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 8db790cf20df
# Removing intermediate container 8db790cf20df
#  ---> eb354a689d09
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in e1e19681ee33
# Removing intermediate container e1e19681ee33
#  ---> c36c72a58470
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 11519863787f
# Removing intermediate container 11519863787f
#  ---> 214cebb81a74
# Step 21/21 : CMD ["bash"]
#  ---> Running in 6260b85a3798
# Removing intermediate container 6260b85a3798
#  ---> 9ff156e05d00
# Successfully built 9ff156e05d00
# Successfully tagged 1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62:latest
# Successfully tagged 1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62:1
# 2022/09/26 19:05:47 Successfully executed container: acb_step_0
# 2022/09/26 19:05:47 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/26 19:05:47 Pushing image: 1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62:1, attempt 1
# The push refers to repository [1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62]
# fb5a911b8aa3: Preparing
# cd304f6f4631: Preparing
# 86379a01bbd1: Preparing
# 8dab1584626c: Preparing
# cbc6aaba164b: Preparing
# fb067fa51273: Preparing
# 9cc9c6191455: Preparing
# a211c3de4373: Preparing
# 74651a3333db: Preparing
# 9a59510b36d4: Preparing
# ae39a55da88b: Preparing
# 8fac15dd911c: Preparing
# a001dd064a81: Preparing
# 7e907f0764b8: Preparing
# 29138effb439: Preparing
# 94f8ff43aced: Preparing
# 982dbd99d0fd: Preparing
# dbfe8c01e73c: Preparing
# 59808e8443ed: Preparing
# af7ed92504ae: Preparing
# fb067fa51273: Waiting
# 9cc9c6191455: Waiting
# 8fac15dd911c: Waiting
# a211c3de4373: Waiting
# 74651a3333db: Waiting
# a001dd064a81: Waiting
# 7e907f0764b8: Waiting
# 9a59510b36d4: Waiting
# 29138effb439: Waiting
# ae39a55da88b: Waiting
# 94f8ff43aced: Waiting
# af7ed92504ae: Waiting
# 982dbd99d0fd: Waiting
# dbfe8c01e73c: Waiting
# 59808e8443ed: Waiting
# fb5a911b8aa3: Pushed
# 8dab1584626c: Pushed
# cbc6aaba164b: Pushed
# cd304f6f4631: Pushed
# 86379a01bbd1: Pushed
# 9cc9c6191455: Pushed
# 74651a3333db: Pushed
# a211c3de4373: Pushed
# 9a59510b36d4: Pushed
# ae39a55da88b: Pushed
# 8fac15dd911c: Pushed
# 94f8ff43aced: Pushed
# 982dbd99d0fd: Pushed
# 7e907f0764b8: Pushed
# a001dd064a81: Pushed
# dbfe8c01e73c: Pushed
# af7ed92504ae: Pushed
# 29138effb439: Pushed
# 59808e8443ed: Pushed
# fb067fa51273: Pushed
# 1: digest: sha256:e5f6e4c4a05c80190be7b072e63018335b0836b570068f33f2244c51c2c70450 size: 4513
# 2022/09/26 19:07:40 Successfully pushed image: 1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62:1
# 2022/09/26 19:07:40 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/26 19:07:40 Pushing image: 1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62:latest, attempt 1
# The push refers to repository [1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62]
# fb5a911b8aa3: Preparing
# cd304f6f4631: Preparing
# 86379a01bbd1: Preparing
# 8dab1584626c: Preparing
# cbc6aaba164b: Preparing
# fb067fa51273: Preparing
# 9cc9c6191455: Preparing
# a211c3de4373: Preparing
# 74651a3333db: Preparing
# 9a59510b36d4: Preparing
# ae39a55da88b: Preparing
# 8fac15dd911c: Preparing
# a001dd064a81: Preparing
# 7e907f0764b8: Preparing
# 29138effb439: Preparing
# 94f8ff43aced: Preparing
# 982dbd99d0fd: Preparing
# dbfe8c01e73c: Preparing
# 59808e8443ed: Preparing
# af7ed92504ae: Preparing
# fb067fa51273: Waiting
# 9cc9c6191455: Waiting
# a211c3de4373: Waiting
# 74651a3333db: Waiting
# 9a59510b36d4: Waiting
# ae39a55da88b: Waiting
# 8fac15dd911c: Waiting
# a001dd064a81: Waiting
# 7e907f0764b8: Waiting
# 29138effb439: Waiting
# 94f8ff43aced: Waiting
# 982dbd99d0fd: Waiting
# dbfe8c01e73c: Waiting
# 59808e8443ed: Waiting
# af7ed92504ae: Waiting
# 86379a01bbd1: Layer already exists
# 8dab1584626c: Layer already exists
# cbc6aaba164b: Layer already exists
# fb5a911b8aa3: Layer already exists
# fb067fa51273: Layer already exists
# a211c3de4373: Layer already exists
# cd304f6f4631: Layer already exists
# 74651a3333db: Layer already exists
# 9cc9c6191455: Layer already exists
# 9a59510b36d4: Layer already exists
# ae39a55da88b: Layer already exists
# 7e907f0764b8: Layer already exists
# a001dd064a81: Layer already exists
# 8fac15dd911c: Layer already exists
# 29138effb439: Layer already exists
# 94f8ff43aced: Layer already exists
# 982dbd99d0fd: Layer already exists
# dbfe8c01e73c: Layer already exists
# af7ed92504ae: Layer already exists
# 59808e8443ed: Layer already exists
# latest: digest: sha256:e5f6e4c4a05c80190be7b072e63018335b0836b570068f33f2244c51c2c70450 size: 4513
# 2022/09/26 19:07:41 Successfully pushed image: 1e8b8819e21c490c89804742dee21367.azurecr.io/azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62:latest
# 2022/09/26 19:07:41 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 155.317545)
# 2022/09/26 19:07:41 Populating digests for step ID: acb_step_0...
# 2022/09/26 19:07:42 Successfully populated digests for step ID: acb_step_0
# 2022/09/26 19:07:42 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 113.011072)
# 2022/09/26 19:07:42 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.337111)
# 2022/09/26 19:07:42 The following dependencies were found:
# 2022/09/26 19:07:42
# - image:
#     registry: 1e8b8819e21c490c89804742dee21367.azurecr.io
#     repository: azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62
#     tag: latest
#     digest: sha256:e5f6e4c4a05c80190be7b072e63018335b0836b570068f33f2244c51c2c70450
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220729.v1
#     digest: sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
#   git: {}
# - image:
#     registry: 1e8b8819e21c490c89804742dee21367.azurecr.io
#     repository: azureml/azureml_adeaed06b760e1f420ccd6c03a5cfa62
#     tag: "1"
#     digest: sha256:e5f6e4c4a05c80190be7b072e63018335b0836b570068f33f2244c51c2c70450
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220729.v1
#     digest: sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
#   git: {}
#
#
# Run ID: cb2 was successful after 4m34s
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# {'runId': 'd9fc46be-bdf1-4c83-a1d2-7043ce751ea8', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-09-26T19:18:34.923231Z', 'endTimeUtc': '2022-09-26T19:20:44.521491Z', 'services': {}, 'properties': {'ContentSnapshotId': '5f810412-e968-47ff-b6be-a848ed4e94de', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c13641d0-24b7-4857-b6d7-74a8ed4d3ba9', 'azureml.moduleName': 'Prepare Data', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'cc5d8339', 'azureml.pipelinerunid': '4b165e02-edf3-458d-94a6-7d6a5f2b76e5', 'azureml.pipeline': '4b165e02-edf3-458d-94a6-7d6a5f2b76e5', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'd74f1c4f-0e71-4983-92f1-3e82562a2676'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [{'identifier': {'savedId': '586d326c-ce2a-496a-b01f-7e71530e7273'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'prepped_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/d9fc46be-bdf1-4c83-a1d2-7043ce751ea8/prepped_data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "586d326c-ce2a-496a-b01f-7e71530e7273",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='Preparation-AI102-Florian', subscription_id='0252a218-2d27-4d77-a4f1-b638272c95e0', resource_group='cloud-shell-storage-westeurope')"
#   }
# }}], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', 'DatasetOutputConfig:prepped_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'your-compute-cluster', 'dataReferences': {}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'd74f1c4f-0e71-4983-92f1-3e82562a2676', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'prepped_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': '4b165e02-edf3-458d-94a6-7d6a5f2b76e5', 'azureml.pipelineRun.moduleNodeId': 'cc5d8339', 'azureml.pipelineRun.outputPortName': 'prepped_data'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '3', 'assetId': 'azureml://locations/westeurope/workspaces/1e8b8819-e21c-490c-8980-4742dee21367/environments/experiment_env/versions/3', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'experiment_env', 'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://preparationai10481060287.blob.core. ...
#
#
#
#
# StepRunId: 5af663ec-e904-42a5-a3f0-a70411fe706b
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5af663ec-e904-42a5-a3f0-a70411fe706b?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# StepRun( Train and Register Model ) Status: Running
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '5af663ec-e904-42a5-a3f0-a70411fe706b', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-09-26T19:20:53.865562Z', 'endTimeUtc': '2022-09-26T19:21:17.724755Z', 'services': {}, 'properties': {'ContentSnapshotId': '5f810412-e968-47ff-b6be-a848ed4e94de', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '71568067-5b7f-468e-8d76-1c2b1d9cdbde', 'azureml.moduleName': 'Train and Register Model', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'fcbbaee6', 'azureml.pipelinerunid': '4b165e02-edf3-458d-94a6-7d6a5f2b76e5', 'azureml.pipeline': '4b165e02-edf3-458d-94a6-7d6a5f2b76e5', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '586d326c-ce2a-496a-b01f-7e71530e7273'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_5c37a30a', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-data', 'DatasetConsumptionConfig:input_5c37a30a'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'your-compute-cluster', 'dataReferences': {}, 'data': {'input_5c37a30a': {'dataLocation': {'dataset': {'id': '586d326c-ce2a-496a-b01f-7e71530e7273', 'name': None, 'version': None}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_5c37a30a', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '3', 'assetId': 'azureml://locations/westeurope/workspaces/1e8b8819-e21c-490c-8980-4742dee21367/environments/experiment_env/versions/3', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'experiment_env', 'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 's ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '4b165e02-edf3-458d-94a6-7d6a5f2b76e5', 'status': 'Completed', 'startTimeUtc': '2022-09-26T19:03:02.622251Z', 'endTimeUtc': '2022-09-26T19:21:19.082083Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://preparationai10481060287.blob.core.windows.net/azureml/ExperimentRun/dcid.4b165e02-edf3-458d-94a6-7d6a5f2b76e5/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=7xzAQlKp7Ny6Uf0GgCz2KziYbSCC5Q86%2BW%2Bt%2BA4rqMk%3D&skoid=5de91831-8610-434c-bc0a-cb0a1b3d5dec&sktid=a2e466aa-4f86-4545-b5b8-97da7c8febf3&skt=2022-09-25T21%3A30%3A26Z&ske=2022-09-27T05%3A40%3A26Z&sks=b&skv=2019-07-07&st=2022-09-26T19%3A08%3A28Z&se=2022-09-27T03%3A18%3A28Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://preparationai10481060287.blob.core.windows.net/azureml/ExperimentRun/dcid.4b165e02-edf3-458d-94a6-7d6a5f2b76e5/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Q2Odz2wgzL%2BYYdD716ugNmnc1wpP%2FB4noiz8tLH4dDM%3D&skoid=5de91831-8610-434c-bc0a-cb0a1b3d5dec&sktid=a2e466aa-4f86-4545-b5b8-97da7c8febf3&skt=2022-09-25T21%3A30%3A26Z&ske=2022-09-27T05%3A40%3A26Z&sks=b&skv=2019-07-07&st=2022-09-26T19%3A08%3A28Z&se=2022-09-27T03%3A18%3A28Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://preparationai10481060287.blob.core.windows.net/azureml/ExperimentRun/dcid.4b165e02-edf3-458d-94a6-7d6a5f2b76e5/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=FcHai3m4AptPFeqrV5a7HZXEK0g2ye4bg5pWMmLVe40%3D&skoid=5de91831-8610-434c-bc0a-cb0a1b3d5dec&sktid=a2e466aa-4f86-4545-b5b8-97da7c8febf3&skt=2022-09-25T21%3A30%3A26Z&ske=2022-09-27T05%3A40%3A26Z&sks=b&skv=2019-07-07&st=2022-09-26T19%3A08%3A28Z&se=2022-09-27T03%3A18%3A28Z&sp=r'}, 'submittedBy': 'Florian Umrani'}
# 'Finished'
# Performing interactive authentication. Please follow the instructions on the terminal.
# Performing interactive authentication. Please follow the instructions on the terminal.

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8984444444444445
# 	 AUC : 0.8831011032550847
# 	 ROC : aml://artifactId/ExperimentRun/dcid.5af663ec-e904-42a5-a3f0-a70411fe706b/ROC_1664220066.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 6
# 	 Training context : Pipeline
# 	 AUC : 0.8831011032550847
# 	 Accuracy : 0.8984444444444445
#
#
# diabetes_model version: 5
# 	 Training context : File dataset
# 	 AUC : 0.8568517900798176
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 4
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568650620553335
# 	 Accuracy : 0.7893333333333333
#
#
# diabetes_model version: 3
# 	 Training context : Parameterized script
# 	 AUC : 0.8482307577491418
# 	 Accuracy : 0.7743333333333333
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8484377332205582
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8483441962286681
# 	 Accuracy : 0.774

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: 416ed1d6-a18a-4aa7-a3e5-ed26e57655e5,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourceGroups/cloud-shell-storage-westeurope/providers/Microsoft.MachineLearningServices/workspaces/Preparation-AI102-Florian/PipelineRuns/PipelineSubmit/416ed1d6-a18a-4aa7-a3e5-ed26e57655e5)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourceGroups/cloud-shell-storage-westeurope/providers/Microsoft.MachineLearningServices/workspaces/Preparation-AI102-Florian/PipelineRuns/PipelineSubmit/416ed1d6-a18a-4aa7-a3e5-ed26e57655e5

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# '0f6b5969-3b29-4550-aa7e-312103fec54f'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 0f6b5969-3b29-4550-aa7e-312103fec54f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0f6b5969-3b29-4550-aa7e-312103fec54f?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# PipelineRun Status: Running
#
#
# StepRunId: 0cdd6b8d-5e1a-42df-aac9-b1027627991f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0cdd6b8d-5e1a-42df-aac9-b1027627991f?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# StepRun( Prepare Data ) Status: Running
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# {'runId': '0cdd6b8d-5e1a-42df-aac9-b1027627991f', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-09-26T20:49:31.65614Z', 'endTimeUtc': '2022-09-26T20:51:26.973478Z', 'services': {}, 'properties': {'ContentSnapshotId': '5f810412-e968-47ff-b6be-a848ed4e94de', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c13641d0-24b7-4857-b6d7-74a8ed4d3ba9', 'azureml.moduleName': 'Prepare Data', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'cc5d8339', 'azureml.pipelinerunid': '0f6b5969-3b29-4550-aa7e-312103fec54f', 'azureml.pipeline': '0f6b5969-3b29-4550-aa7e-312103fec54f', 'azureml.pipelineid': '416ed1d6-a18a-4aa7-a3e5-ed26e57655e5', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'd74f1c4f-0e71-4983-92f1-3e82562a2676'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [{'identifier': {'savedId': '28ba2542-f951-40d7-896e-09642fa17752'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'prepped_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/0cdd6b8d-5e1a-42df-aac9-b1027627991f/prepped_data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "28ba2542-f951-40d7-896e-09642fa17752",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='Preparation-AI102-Florian', subscription_id='0252a218-2d27-4d77-a4f1-b638272c95e0', resource_group='cloud-shell-storage-westeurope')"
#   }
# }}], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', 'DatasetOutputConfig:prepped_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'your-compute-cluster', 'dataReferences': {}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'd74f1c4f-0e71-4983-92f1-3e82562a2676', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'prepped_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': '0f6b5969-3b29-4550-aa7e-312103fec54f', 'azureml.pipelineRun.moduleNodeId': 'cc5d8339', 'azureml.pipelineRun.outputPortName': 'prepped_data'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '3', 'assetId': 'azureml://locations/westeurope/workspaces/1e8b8819-e21c-490c-8980-4742dee21367/environments/experiment_env/versions/3', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'experiment_env', 'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'logs/azureml/dataprep/0/backgroundProcess.log': 'https://preparationai10481060287. ...
#
#
#
#
# StepRunId: ac5efb70-5ceb-4871-af57-e664b3145688
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ac5efb70-5ceb-4871-af57-e664b3145688?wsid=/subscriptions/0252a218-2d27-4d77-a4f1-b638272c95e0/resourcegroups/cloud-shell-storage-westeurope/workspaces/Preparation-AI102-Florian&tid=a2e466aa-4f86-4545-b5b8-97da7c8febf3
# StepRun( Train and Register Model ) Status: Running
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': 'ac5efb70-5ceb-4871-af57-e664b3145688', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-09-26T20:51:36.399739Z', 'endTimeUtc': '2022-09-26T20:51:59.599396Z', 'services': {}, 'properties': {'ContentSnapshotId': '5f810412-e968-47ff-b6be-a848ed4e94de', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '71568067-5b7f-468e-8d76-1c2b1d9cdbde', 'azureml.moduleName': 'Train and Register Model', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'fcbbaee6', 'azureml.pipelinerunid': '0f6b5969-3b29-4550-aa7e-312103fec54f', 'azureml.pipeline': '0f6b5969-3b29-4550-aa7e-312103fec54f', 'azureml.pipelineid': '416ed1d6-a18a-4aa7-a3e5-ed26e57655e5', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '28ba2542-f951-40d7-896e-09642fa17752'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_5c37a30a', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-data', 'DatasetConsumptionConfig:input_5c37a30a'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'your-compute-cluster', 'dataReferences': {}, 'data': {'input_5c37a30a': {'dataLocation': {'dataset': {'id': '28ba2542-f951-40d7-896e-09642fa17752', 'name': None, 'version': None}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_5c37a30a', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '3', 'assetId': 'azureml://locations/westeurope/workspaces/1e8b8819-e21c-490c-8980-4742dee21367/environments/experiment_env/versions/3', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'experiment_env', 'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '0f6b5969-3b29-4550-aa7e-312103fec54f', 'status': 'Completed', 'startTimeUtc': '2022-09-26T20:43:47.224223Z', 'endTimeUtc': '2022-09-26T20:52:00.871459Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineid': '416ed1d6-a18a-4aa7-a3e5-ed26e57655e5', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://preparationai10481060287.blob.core.windows.net/azureml/ExperimentRun/dcid.0f6b5969-3b29-4550-aa7e-312103fec54f/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=i4tJwuTswRghqZ9zc4R0mzXnZdC0GwRX8P8QqOm4Pfo%3D&skoid=5de91831-8610-434c-bc0a-cb0a1b3d5dec&sktid=a2e466aa-4f86-4545-b5b8-97da7c8febf3&skt=2022-09-26T18%3A53%3A06Z&ske=2022-09-28T03%3A03%3A06Z&sks=b&skv=2019-07-07&st=2022-09-26T20%3A42%3A06Z&se=2022-09-27T04%3A52%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://preparationai10481060287.blob.core.windows.net/azureml/ExperimentRun/dcid.0f6b5969-3b29-4550-aa7e-312103fec54f/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=v1tosD2RfQsuKMukE%2BOEYougc0%2BSYdQOJVY%2B%2BRSzp3c%3D&skoid=5de91831-8610-434c-bc0a-cb0a1b3d5dec&sktid=a2e466aa-4f86-4545-b5b8-97da7c8febf3&skt=2022-09-26T18%3A53%3A06Z&ske=2022-09-28T03%3A03%3A06Z&sks=b&skv=2019-07-07&st=2022-09-26T20%3A42%3A06Z&se=2022-09-27T04%3A52%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://preparationai10481060287.blob.core.windows.net/azureml/ExperimentRun/dcid.0f6b5969-3b29-4550-aa7e-312103fec54f/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=D0Wtit0sWK6vLrrOaxGoDobeL41%2FN4zoK26hn4UNxkM%3D&skoid=5de91831-8610-434c-bc0a-cb0a1b3d5dec&sktid=a2e466aa-4f86-4545-b5b8-97da7c8febf3&skt=2022-09-26T18%3A53%3A06Z&ske=2022-09-28T03%3A03%3A06Z&sks=b&skv=2019-07-07&st=2022-09-26T20%3A42%3A06Z&se=2022-09-27T04%3A52%3A06Z&sp=r'}, 'submittedBy': 'Florian Umrani'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
